# %%
import os
import pandas as pd
from PIL import Image
from PIL import ImageDraw
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import cv2
import json

# %%
x = np.array(list(range(17)) * 100)

# %%
y = 400 + 10 * x + np.random.normal(0, 30, len(x))

# %%
sns.set_theme()
plt.scatter(x, y)
# plt.title("Ideal Prompt")
plt.xlabel("Lemma- Length")
plt.ylabel("BB - Length")
# Out:
# Text(0, 0.5, 'BB - Length')
