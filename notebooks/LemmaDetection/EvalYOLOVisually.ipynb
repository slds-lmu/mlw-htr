# %% [markdown]
# # Imports

# %%
import cv2

from ultralytics import YOLO

# %% [markdown]
# # Constants

# %%
path_model: str = "/home/USER/runs/detect/train4/weights/best.pt"
path_img: str = "/home/USER/Documents/Uni/WiSe2223/Consulting/mlw-consulting-project/zettel/952.jpg"

# %% [markdown]
# # Model Def

# %%
model = YOLO(path_model)

# %%
predictions = model([path_img]).cpu() # TODO: change to appropriate `device`

# %% [markdown]
# # Prediction

# %%
for prediction in predictions:
    print(prediction.boxes.xyxyn)
    print(prediction.boxes.conf)
    print(prediction.boxes.cls)

# %%
cv2.rectangle(
    img,
    (int(e['x1']), int(e['y1'])),
    (int(e['x2']), int(e['y2'])),
    (0, 255, 0),
    3
)
